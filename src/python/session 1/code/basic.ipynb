# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = "Youssef"
age = 23
course_name = "Python Programming"
output = f"My name is {name}, I am {age} years old, and I am taking the course {course_name}."
print(output)
# Out:
# My name is Youssef, I am 23 years old, and I am taking the course Python Programming.
