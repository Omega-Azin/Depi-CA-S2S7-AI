# %%
list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]
x = input("Enter the item you want to remove from the list: ")
list.remove(x)
list
# Out:
# ['amit', 'learning', 'machine learning', 'data science', 'deep learning']

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
sum = num1 + num2
sub = num1 - num2
multi = num1 * num2
div = num1 / num2
print(sum)
print(sub)
print(multi)
print(div)
# Out:
# 15.0
# 5.0
# 50.0
# 2.0
